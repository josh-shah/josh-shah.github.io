# %% [markdown]
# <a href="https://colab.research.google.com/github/josh-shah/josh-shah.github.io/blob/main/MKT_VALUEvsWAGESMERGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv('2022-11-15_Squads_GB1.csv')
df2=pd.read_csv('capology_clean.csv',skiprows=1)

# %%
df1.head(3)
# Out:
#    player_id          player  club_id        club       main_position  \
# 0     111455    Granit Xhaka       11  Arsenal FC    Central Midfield
# 1     112988   Cédric Soares       11  Arsenal FC          Right-Back
# 2     160438  Mohamed Elneny       11  Arsenal FC  Defensive Midfield
#
#       market_value market_value_GBP
# 0  € 28,000,000.00      £24,640,000
# 1   € 4,000,000.00       £3,520,000
# 2   € 9,000,000.00       £7,920,000

# %%
df2.head(3)
# Out:
#    Unnamed: 0  0               Player  weekly_wage Pos. DFKM  \
# 0           0  1        Gabriel Jesus  £265,000.00         F
# 1           1  2        Thomas Partey  £200,000.00         M
# 2           2  3  Oleksandr Zinchenko  £150,000.00         D
#
#   Pos. AMCBCFCMDMGKLBLWRBRMRW  Age  Country     Team  Premier League  \
# 0                          CF   25   Brazil  Arsenal  Premier League
# 1                          DM   29    Ghana  Arsenal  Premier League
# 2                          LB   25  Ukraine  Arsenal  Premier League
#
#    2022-2023
# 0  2022-2023
# 1  2022-2023
# 2  2022-2023

# %%
len(df1),len(df2)
# Out:
# (510, 451)

# %%
df1=df1.set_index('player')
df2=df2.set_index('Player')

# %%
set(df1.index).difference(set(df2.index)) #players in df1 but not in df2
# Out:
# {'Aaron Hickey',
#  'Adnan Kanuric',
#  'Ainsley Maitland-Niles',
#  'Aleksandar Mitrović',
#  'Armel Bella-Kotchap',
#  'Arthur Melo',
#  'Ben Mee',
#  'Bernd Leno',
#  'Billy Gilmour',
#  'Boubacar Traoré',
#  'Brenden Aaronson',
#  'Caoimhín Kelleher',
#  'Carlos Vinícius',
#  'Cheick Doucouré',
#  'Cheikhou Kouyaté',
#  'Chris Richards',
#  'Deniz Undav',
#  'Duje Caleta-Car',
#  'Emerson Royal',
#  'Emmanuel Dennis',
#  'Gavin Bazunu',
#  'Giulian Biancone',
#  'Gonçalo Guedes',
#  'Harry Toffolo',
#  'Issa Diop',
#  'Jeremy Sarmiento',
#  'Joe Aribo',
#  'Joel Robles',
#  'Josh Dasilva',
#  'João Palhinha',
#  'Juan Larios',
#  'Julio Enciso',
#  'Kaoru Mitoma',
#  'Keane Lewis-Potter',
#  'Kevin Mbabu',
#  'Levi Colwill',
#  "Lewis O'Brien",
#  'Luis Sinisterra',
#  'Malcolm Ebiowei',
#  'Manor Solomon',
#  'Marc Roca',
#  'Martin Dúbravka',
#  'Mason Greenwood',
#  'Mikkel Damsgaard',
#  'Morgan Gibbs-White',
#  'Moussa Niakhaté',
#  'Nathan Collins',
#  'Neco Williams',
# ...

# %%
set(df2.index).difference(set(df1.index)) #players in df2 but not in df1
# Out:
# {'Aleksandar Mitrovic',
#  'Arthur',
#  'Caoimhin Kelleher',
#  'Chem Campbell',
#  'Joshua Da Silva',
#  'Keinan Davis',
#  'Martin Dubravka',
#  'Shola Shoretire',
#  'Stefan Ortega Moreno',
#  'Toti Gomes'}

# %%
df3 = df1.join(df2,how='inner') #only the overlapping

# %%
df3
# Out:
#                     player_id  club_id                     club  \
# Aaron Cresswell         92571      379          West Ham United
# Aaron Ramsdale         427568       11               Arsenal FC
# Aaron Wan-Bissaka      477758      985        Manchester United
# Abdoulaye Doucouré     127187       29               Everton FC
# Adam Armstrong         250426      180           Southampton FC
# ...                       ...      ...                      ...
# Yerry Mina             289446       29               Everton FC
# Yerson Mosquera        716276      543  Wolverhampton Wanderers
# Yoane Wissa            388165     1148             Brentford FC
# Youri Tielemans        249565     1003           Leicester City
# Yves Bissouma          410425      148        Tottenham Hotspur
#
#                        main_position     market_value market_value_GBP  \
# Aaron Cresswell            Left-Back   € 2,500,000.00       £2,200,000
# ...

# %%
exported_values = list(df3.T.to_dict().values() )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %%
import csv

# %%
from google.colab import files

df3.to_csv('MKT_VALUEvsWAGES.csv', encoding = 'utf-8-sig') 
files.download('MKT_VALUEvsWAGES.csv')

# %%
df1.join(df2,how='outer') #everyone
# Out:
#                     player_id  club_id                     club  \
# Aaron Cresswell       92571.0    379.0          West Ham United
# Aaron Hickey         591949.0   1148.0             Brentford FC
# Aaron Ramsdale       427568.0     11.0               Arsenal FC
# Aaron Wan-Bissaka    477758.0    985.0        Manchester United
# Abdoulaye Doucouré   127187.0     29.0               Everton FC
# ...                       ...      ...                      ...
# Yerson Mosquera      716276.0    543.0  Wolverhampton Wanderers
# Yoane Wissa          388165.0   1148.0             Brentford FC
# Youri Tielemans      249565.0   1003.0           Leicester City
# Yves Bissouma        410425.0    148.0        Tottenham Hotspur
# Zanka                 52059.0   1148.0             Brentford FC
#
#                        main_position     market_value market_value_GBP  \
# Aaron Cresswell            Left-Back   € 2,500,000.00       £2,200,000
# ...
