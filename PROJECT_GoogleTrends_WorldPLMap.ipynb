# %% [markdown]
# <a href="https://colab.research.google.com/github/josh-shah/josh-shah.github.io/blob/main/PROJECT_GoogleTrends_WorldPLMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16127 sha256=fa1961009efa8988fd85c03c59138f19573aa7ac0c540926a57163bae1000427
#   Stored in directory: /root/.cache/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...

# %%
import pandas as pd

#Import TrendReq to connect to Google
from pytrends.request import TrendReq

#Use exact keyword codes (found in https://colab.research.google.com/drive/1lTSIMgRJMBXQMXSvKt-CDEE_zunOsZEF#scrollTo=VC_k3IiFTwXx) to avoid ambiguity, trying Team names led to inaccurate results. 
list1=['/m/050fh','/m/0xbm','/m/04ltf	','/m/023fb	','/m/01634x'] #Man U, Arsenal, Liverpool, Chelsea, Man City

pytrends1=TrendReq()  

#build payload for both the lists and pass parameters to filter the data for trend comparison based on our requirements
pytrends1.build_payload(list1,timeframe='today 12-m')

df1=pytrends1.interest_by_region(resolution='COUNTRY', inc_low_vol=True, inc_geo_code=True)

# %%
df1
# Out:
#                geoCode  /m/050fh  /m/0xbm\t  /m/04ltf\t  /m/023fb\t  /m/01634x
# geoName
# Afghanistan         AF        36          7          21          16         20
# Albania             AL        25          9          29          18         19
# Algeria             DZ        17          4          19           8         52
# American Samoa      AS         0          0           0           0          0
# Andorra             AD        24          7          19          18         32
# ...                ...       ...        ...         ...         ...        ...
# Western Sahara      EH        20          6          28          22         24
# Yemen               YE        22          7          39          12         20
# Zambia              ZM        28         13          20          21         18
# Zimbabwe            ZW        26         14          22          20         18
# Åland Islands       AX        18         16          43          13         10
#
# ...

# %%
df1.rename(columns = {'/m/050fh':'Manchester United','/m/0xbm\t':'Arsenal','/m/04ltf\t':'Liverpool','/m/023fb\t':'Chelsea','/m/01634x':'Manchester City'}, inplace = True)

# %%
df1
# Out:
#                geoCode  Manchester United  Arsenal  Liverpool  Chelsea  \
# geoName
# Afghanistan         AF                 36        7         21       16
# Albania             AL                 25        9         29       18
# Algeria             DZ                 17        4         19        8
# American Samoa      AS                  0        0          0        0
# Andorra             AD                 24        7         19       18
# ...                ...                ...      ...        ...      ...
# Western Sahara      EH                 20        6         28       22
# Yemen               YE                 22        7         39       12
# Zambia              ZM                 28       13         20       21
# Zimbabwe            ZW                 26       14         22       20
# Åland Islands       AX                 18       16         43       13
#
#                 Manchester City
# geoName
# Afghanistan                  20
# ...

# %%
exported_values = list(df1.T.to_dict().values() )

# %%
import csv

# %%
from google.colab import files

df1.to_csv('mostpopularteams_project.csv', encoding = 'utf-8-sig') 
files.download('mostpopularteams_project.csv')

# %%
#South Korea is the only country which has a most popular team outside of these top 5 (Tottenham Hotspur) with a score of 30. We will manually change this in the final dataset.
